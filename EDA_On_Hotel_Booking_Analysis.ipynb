# %% [markdown]
# <a href="https://colab.research.google.com/github/AbhishekThakur0126/EDA-Hotel-Booking-Analysis/blob/main/EDA_On_Hotel_Booking_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![jerry-zhang-_M483nnWCa0-unsplash (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA On HOTEL BOOKING ANALYSIS
# ##### **Contribution**    - TEAM
# ##### **Team Member 1 -** ABHISHEK THAKUR
# ##### **Team Member 2 -** VIRENDER SINGH

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project is related to Hotel Booking and involves two types of hotels: City Hotel and Resort Hotel. The dataset contains a total of 119,390 rows and 32 columns. The data manipulation workflow is divided into three categories: Data Collection, Data Cleaning and Manipulation, and EDA (Exploratory Data Analysis).
#
# To begin with Data Collection, we used various methods such as head(), tail(), info(), describe(), and columns() to explore the dataset and identify different columns. Some of the important columns in this dataset include: hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, and stays_in_weekend_nights.
#
# Moving further, we found the unique values for each column and generated a list in tabular form. We also checked the data type of each column and identified some columns that were not in the correct data types. These discrepancies were addressed and corrected during the Data Cleaning phase. Additionally, duplicate data items were identified, and 87,396 duplicates were removed from the dataset.
#
# Before visualizing any data from the dataset, we performed data wrangling. This involved checking for null values in all the columns. Columns with a high number of null values were dropped using the 'drop' method. The 'company' column, for example, was dropped due to its high number of null values. For columns with a minimal number of null values, the missing values were filled using appropriate methods and necessary values, achieved through the .fillna() method.
#
# Various charts were then utilized for data visualization in order to gain better insights and achieve the project's business objectives.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/AbhishekThakur0126/EDA-Hotel-Booking-Analysis

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered about the best time of year to book a hotel room or the optimal length of stay in order to get the best daily rate? Have you ever wanted to predict whether a hotel is likely to receive a disproportionately high number of special requests? This hotel booking dataset can assist you in exploring these questions. The dataset contains booking information for both a city hotel and a resort hotel. It includes details such as the booking date, length of stay, the number of adults, children, and/or babies, and the availability of parking spaces, among other factors. All personally identifying information has been removed from the dataset. Explore and analyze the data to uncover the significant factors that influence the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Let's analyze the data on bookings for both the City Hotel and Resort Hotel to gain insights into the various factors that impact the booking process.
#
# By examining the data, we can uncover important details about the bookings and understand the factors that influence them. This analysis will provide valuable insights into the different aspects that affect the booking experience in both types of hotels.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
hotl_df = pd.read_csv('/content/drive/MyDrive/Hotel Booking Analysis EDA DataSet/Hotel Bookings.csv')
hotl_df

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
hotl_df

# %%
hotl_df.head()

# %%
hotl_df.tail()

# %%
hotl_df.shape

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Number of Rows : ', len(hotl_df.axes[0]))
print('Number of Columns : ', len(hotl_df.axes[1]))

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
hotl_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
hotl_df.duplicated().sum()

# %%
# drop duplicates values
hotl_df.drop_duplicates(inplace = True)

# %%
# Shape of dataset
hotl_df.shape

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
hotl_df.isnull().sum()

# %%
# Visualizing the missing values
plt.figure(figsize=(12,5))
sns.heatmap(hotl_df.isnull())
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset consists of a single file that compares various booking information between two hotels: a city hotel and a resort hotel. It includes details such as the booking date, length of stay, the number of adults, children, and/or babies, and the availability of parking spaces, among other factors. The dataset contains a total of 119,390 rows and 32 columns. Initially, there were duplicated items, amounting to 31,944, which were subsequently removed from the dataset. We examine the data types of each column and observe that some columns have inaccurate data types, which will be corrected later. Additionally, we explore the unique values present in each column to gain a better understanding of the dataset.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotl_df.columns

# %%
# Dataset Describe
hotl_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **The columns and the data it represents are listed below:**
#
# 1. **hotel :** Name of the hotel (Resort Hotel or City Hotel)
#
# 2. **is_canceled :** If the booking was canceled (1) or not (0)
#
# 3. **lead_time:** Number of days before the actual arrival of the guests
#
# 4. **arrival_date_year :** Year of arrival date
#
# 5. **arrival_date_month :** Month of month arrival date
#
# 6. **arrival_date_week_number :** Week number of year for arrival date
#
# 7. **arrival_date_day_of_month :** Day of arrival date
#
# 8. **stays_in_weekend_nights :** Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# 9. **stays_in_week_nights :** Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# 10. **adults :** Number of adults among guests
#
# 11. **children :** Number of children among guests
#
# 12. **babies :** Number of babies among guests
#
# 13. **meal :** Type of meal booked
#
# 14. **country :** Country of guests
#
# 15. **market_segment :** Designation of market segment
#
# 16. **distribution_channel :** Name of booking distribution channel
#
# 17. **is_repeated_guest :** If the booking was from a repeated guest (1) or not (0)
#
# 18. **previous_cancellations :** Number of previous bookings that were cancelled by the customer prior to the current booking
#
# 19. **previous_bookings_not_canceled :** Number of previous bookings not cancelled by the customer prior to the current booking
#
# 20. **reserved_room_type :** Code of room type reserved
#
# 21. **assigned_room_type :** Code of room type assigned
#
# 22. **booking_changes :** Number of changes/amendments made to the booking
#
# 23. **deposit_type :** Type of the deposit made by the guest
#
# 24. **agent :** ID of travel agent who made the booking
#
# 25. **company :** ID of the company that made the booking
#
# 26. **days_in_waiting_list :** Number of days the booking was in the waiting list
#
# 27. **customer_type :** Type of customer, assuming one of four categories
#
# 28. **adr :** Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# 29. **required_car_parking_spaces :** Number of car parking spaces required by the customer
#
# 30. **total_of_special_requests :** Number of special requests made by the customer
#
# 31. **reservation_status :** Reservation status (Canceled, Check-Out or No-Show)
#
# 32. **reservation_status_date :** Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(hotl_df.apply(lambda col: col.unique()))

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df = hotl_df.copy()

# %%
df.columns

# %%
# checking for null values after replacing them
df.isnull().sum()

# %%
# dropping the 'company' column as it contains a lot of null values in coparison to other columns
df.drop(['company'], axis =1 , inplace = True)

# %%
# dropping rows where no adults , children and babies are available because no bookings were made that day

no_guest = df[df['adults']+df['babies']+df['children']==0]
df.drop(no_guest.index, inplace=True)

# %%
# adding some new columns to make our data analysis ready
df['total_people'] = df['adults'] + df['babies'] + df['children']       # creating total people column by adding all the people in that booking

df['total_stay'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']    # creating a column to check total stay in hotel

# %%
# having a final look to check if our dataset is ready to analyse
df.head()

# %%
# checking the final shape of the dataset
print( 'final shape of the dataset is', df.shape)

# %%
# checking the unique values which is to be analysed
pd.Series({col:df[col].unique() for col in df})

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I first created a copy of the dataset before performing any manipulations. Then, I filled missing values with 0 in the 'children', 'company', and 'agent' columns since they contained numerical values. For the 'country' column, I filled missing values with 'others' as a placeholder. As the 'country' column had 96% missing values and was not useful for our analysis, I dropped it from the dataset.
#
# Next, I created two new columns named 'total_people' and 'total_stay' for further analysis. In the 'total_people' column, I calculated the total number of babies, children, and adults. Similarly, in the 'total_stay' column, I added the values from the 'weekend_stay' and 'week_stay' columns.
#
# After completing all the manipulations, I checked the new manipulated dataset to ensure it was ready for analysis.
#
# Based on the manipulated dataset, here are the insights I discovered:
#
# 1. There are two types of hotels available for booking, allowing us to determine which type of hotel was booked the most.
#
# 2. Guests come from different countries, indicating diverse international bookings.
#
# 3. Guests have the option to choose from a variety of food items from the menu.
#
# 4. Guests can book hotels directly or through various available channels.
#
# 5. The dataset includes information about canceled bookings and also records repeated guests.
#
# 6. Guests have the flexibility to select rooms of their preference during the booking process.
#
# 7. The dataset contains a column named 'adr' that can be used to analyze the hotel's performance based on revenue.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Count Hotel
hotel_count = df.hotel.value_counts()

# Define the colors
colors = ['#40E0D0', '#6495ED', '#DFFF00']

# Plotting Values in a simple pie chart with custom colors
hotel_count.plot.pie(figsize=(9, 7), autopct='%1.2f%%', shadow=True, fontsize=15, startangle=50, colors=colors)

# Setting the title
plt.title('Hotel Booking Percentage')

plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used a pie chart as it provides a better visual representation of the hotel booking distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here, we found that the booking number is higher in the City Hotel, accounting for 61.12%, compared to the Resort Hotel, which represents 38.87%. Hence, we can conclude that the City hotel has a higher level of consumption.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight is useful for stakeholders to assess which hotel is performing the best and where they can allocate more capital. Although there is no negative growth observed, stakeholders can prioritize the City Hotel to attract more bookings and increase overall revenue. By focusing on enhancing the performance of the City Hotel, stakeholders can capitalize on its popularity and drive further growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Counting each meal type
meal_count = df.meal.value_counts()

# Extracting each meal type and storing in a variable
meal_name = df['meal'].unique()

# Creating a dataset of each meal type and count
meal_df = pd.DataFrame(zip(meal_name,meal_count), columns = ['meal name', 'meal count'])

# Visualising the values on a bar chart
plt.figure(figsize=(15,5))
g = sns.barplot(data=meal_df, x='meal name', y ='meal count')
g.set_xticklabels(meal_df['meal name'])
plt.title('Most preffered meal type', fontsize=25)
plt.show()

# %% [markdown]
# Meal type variable description:
#
# BB - (Bed and Breakfast)
#
# HB- (Half Board)
#
# FB- (Full Board)
#
# SC- (Self Catering)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since we had four values to compare, I used a bar graph. Bar graphs are commonly employed to compare different groups or categories, making them suitable for visualizing this type of data comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# After visualizing the above chart, it is evident that BB (Bed and Breakfast) is the most preferred meal type among guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, based on the insight gained above, stakeholders now understand that BB (Bed and Breakfast) is the most preferred meal type among guests. Armed with this knowledge, stakeholders can proactively arrange the necessary raw materials for this meal in advance, ensuring smooth operations and timely delivery of the preferred meal option to guests.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# 1 is for booking made by repeated guest and 0 is for booking not made by repeated guest
repeated_guests_count = df['is_repeated_guest'].value_counts()
repeated_guests_count

# %%
# barplot is used for visaulization
colors = ['#6495ED', '#40E0D0'] #Specify colour of plot
repeated_guests_count.plot.pie(explode=[0.03, 0.03], autopct='%1.2f%%', shadow=True, figsize=(10,7), fontsize=20, colors=colors)
plt.title('Percentage of repeated guests', fontsize=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to use a pie chart because it provides a simple and easy-to-understand visualization that demonstrates the frequency of guests booking a particular hotel repeatedly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight derived from the chart indicates that there are very few guests who book the same hotel again.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights gained can create a positive business impact. Hotels that do not have repeated guests can take feedback from their guests and make efforts to improve their services. This feedback-driven approach can help enhance the guest experience and attract more repeat bookings in the future.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# ploting graph for booking in different months
plt.figure(figsize=(15,5))
sns.countplot(x=df['arrival_date_month'],hue=df['hotel'])
plt.title("Number of booking across months", fontsize = 25)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to use a bar chart because it is one of the best choices for comparing values across different months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above insight indicates that August and July were the busiest months compared to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# While there is a negative aspect to the insight, the hotel can leverage this information to make necessary preparations in advance and ensure a warm welcome for their guests. Additionally, the hotel can seize the opportunity to run promotional offers during the remaining months to attract more guests and increase bookings.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
room_type = df['assigned_room_type'].value_counts()
room_type

# %%
# countlot is used for visualization of most preferred room type
plt.figure(figsize=(14,7))
sns.countplot(x=df['assigned_room_type'],order=df['assigned_room_type'].value_counts().index)
plt.title("Most preferred Room type", fontsize = 20)
plt.xlabel('Type of the Room', fontsize = 15)
plt.ylabel('Room type count', fontsize = 15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to use a countplot to visualize the most preferred room types because it displays the count of each observation for each category. In this case, we are representing the room type versus the count of each room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight derived from the chart reveals that A type rooms are the most preferred rooms, with a count of 46,283. Following that, D type rooms are preferred by guests, with a count of 22,419. On the other hand, L type rooms are the least preferred among all room types.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight obtained from the chart indicates that A type rooms are the most preferred rooms, which positively impacts the business due to their high booking count of 46,283. However, H, I, K, and L type rooms are less preferred, with L type rooms having only one booking. This insight highlights a negative impact on the business for these less preferred room types.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# distribution channel value count
distribution_channel_counts = df['distribution_channel'].value_counts()
distribution_channel_counts

# %%
d3 = df.shape[0]
d3

# %%
# distribution channel count in df format
distribution_channel_df = df['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})
distribution_channel_df

# %%
# booking by distribution channel in percent
distribution_channel_df_percent = pd.DataFrame(round((distribution_channel_counts/d3)*100,2)).reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'% booking'})
distribution_channel_df_percent

# %%
#Visualization of mostly used distribution channels using barplot
plt.figure(figsize=(14,7))
sns.barplot(data=distribution_channel_df_percent, x="distribution_channel", y="% booking")
plt.title("Mostly used distribution Channels", fontsize = 20)
plt.xlabel('Distribution Channel', fontsize = 15)
plt.ylabel('Booking by distribution channel in percent', fontsize = 15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot provides a simple and easy-to-understand graphical representation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most commonly used distribution channel is the TA/TO (Travel Agent/ Tour Operator) channel. The total count of bookings through this channel is 69,028, which accounts for 79.13% of the total bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The TA/TO (Travel Agent/ Tour Operator) distribution channel is the most widely used channel, which has a positive impact. On the other hand, the GDS (Global Distribution System) and undefined channels are less utilized, resulting in a negative impact. The usage of the TA/TO channel accounts for 79.13% of the bookings, while the usage of the GDS channel is only 0.21%.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
Waiting_time = df.groupby('hotel')['days_in_waiting_list'].mean().reset_index()
Waiting_time

# %%
# Visualization of hotel which has longer waiting time by using barplot
plt.figure(figsize=(14,7))
sns.barplot(x=Waiting_time['hotel'],y=Waiting_time['days_in_waiting_list'])
plt.title('Waiting time for each hotel type', fontsize=20)
plt.xlabel('Type of hotel',fontsize=15)
plt.ylabel('Waiting time', fontsize=15)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to use a bar plot because it provides an easy-to-understand visual representation to compare the waiting times between hotels and determine which hotel has a longer waiting time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot indicates that the City hotel has a longer waiting time, suggesting that it is busier compared to the Resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The City hotel having a longer waiting time can have a positive impact on business, indicating higher demand. However, the Resort hotel having a shorter waiting time may have a negative impact on business, suggesting lower demand or faster booking fulfillment. The mean number of days in the waiting list for the City hotel is approximately 1.02, while for the Resort hotel, it is around 0.32. To increase their bookings, the Resort hotel should consider improving their facilities and services to attract more guests.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
cust_type = df['customer_type'].value_counts()

# Plotting the values in a line chart
cust_type.plot(figsize=(15,5))

# Setting the x label , y label and title
plt.xlabel('Count', fontsize=8)
plt.ylabel('Customer Type', fontsize=10)
plt.title('Customer Type and their booking count', fontsize=20)

# Show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line graphs are used to track changes over different categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the Transient customer type has the most number of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotels can run promotional offers to increase the number of bookings over other categories, such as offering discounts for groups.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Setting the figure size
plt.figure(figsize=(15,5))

# Plotting the values
sns.countplot(x=df['assigned_room_type'], order = df['assigned_room_type'].value_counts().index)

# Setting the title
plt.title('Assigned Room Type to Guests', fontsize = 20)

# show the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot shows categorical data as rectangular bars, with the height of the bars proportional to the values they represent.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart, it is clear that room type A is most frequently assigned to guest

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In the 8th chart, we observed that around 55,000 guests preferred room type A, but only 45,000 people were assigned A type rooms. This could be a reason to consider canceling some bookings. The hotel could increase the availability of A type rooms to decrease the likelihood of cancellations.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Grouping arrival_month and hotel on mean of adr
bookings_months = df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index()

# Creating a month list to order the months in ascending
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# Creating a dataset of months, hotel and their adr
bookings_months['arrival_date_month'] = pd.Categorical(bookings_months['arrival_date_month'],categories=months,ordered=True)

# Sorting the months
bookings_months=bookings_months.sort_values('arrival_date_month')
bookings_months

# %%
# Setting the chart size
plt.figure(figsize=(15,5))

# Plotting the values in a line chart
sns.lineplot(x=bookings_months['arrival_date_month'],y=bookings_months['adr'],hue=bookings_months['hotel'])

# Setting the labels and title
plt.title('ADR across each month', fontsize=20)
plt.xlabel('Month Name', fontsize=12)
plt.ylabel('ADR', fontsize=12)

# Show chart
plt.show()

# %% [markdown]
# City Hotel : It is clear that City Hotel generates more revenue in May months in comparison to other months.
#
# Resort Hotel : Resort Hotel generates more revenue in between July and August months.
#
# Stakeholders could prepare in advance for these 2 months as these 2 months generate more revenue.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We used a line plot because it provides a better understanding of the months' names over the Average Daily Rate (ADR).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the City Hotel has a higher Average Daily Rate (ADR) compared to the Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights from the above line plot indicate that we need to run promotional offers on the Resort Hotel to increase its Average Daily Rate (ADR) throughout the year.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'adr', x = 'total_stay', data = df)
plt.show()

# %%
df.drop(df[df['adr'] > 5000].index, inplace = True)

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'adr', x = 'total_stay', data = df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We are using a scatter plot because it helps me to understand the relationship between total stays and ADR (Average Daily Rate).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that the 0-20 range has a higher ADR compared to others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insight from the above scatter plot is that we need to run promotional offers for the remaining ranges to increase their ADR.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
fig, axes = plt.subplots(1, 2, figsize=(18, 8))

grp_by_room = df.groupby('assigned_room_type')
df['Num_of_bookings'] = grp_by_room.size()

sns.countplot(ax = axes[0], x = df['assigned_room_type'])
sns.boxplot(ax = axes[1], x = df['assigned_room_type'], y = df['adr'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked this countplot and boxplot for a better representation of the rooms chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that A and D type rooms are more booked as compared to others..

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights from the above plot indicate that we need to reduce tariffs to increase bookings for other room types as well.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# Grouping dist_channel and hotels on their adr
dist_channel_adr = df.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()

# Setting the figure size
plt.figure(figsize=(15,5))

# Creating a horizontal bar chart
sns.barplot(x='adr', y='distribution_channel', data=dist_channel_adr, hue='hotel')

# Setting the title
plt.title('ADR across each distribution channel', fontsize=20)

# Show chart
plt.show()

# %% [markdown]
# GDS has contributed more in generating the ADR. GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
#
# Direct- means that bookings are directly made with the respective hotels
#
# TA/TO- means that booings are made through travel agents or travel operators.
#
# Undefined- Bookings are undefined. may be customers made their bookings on arrival.

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We picked a bar plot as it represents data in a more understandable manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights from the above plot show that GDS and direct reservations have a higher ADR compared to others

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We need to run promotional offers for other distribution channels to increase their ADR as well.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Setting the chart size
plt.figure(figsize=(15,10))

# Creating heatmap to see correlation of each columns
sns.heatmap(df.corr(numeric_only=True),annot=True)          # Setting the numeric only colun to True to avoid warning

# Setting the title
plt.title('Correlation of the columns', fontsize=20)

# Show heatmap
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps were used to find potential relationships between variables and to understand the strength of these relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lead time and total stay are positively correlated, which means that if customers stay longer, the lead time increases.
#
# Adults, children, and babies are correlated with each other. This implies that the more people there are (adults, children, and babies combined), the higher the ADR may be.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pairs plot allows us to see both the distribution of single variables and the relationships between two variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see the relationship between all the columns in the above chart.
#
# From the pair plot, it is evident that if cancellations increase, then total stay also decreases. Additionally, as the total number of people increases, the ADR also increases.
#
# Thus, ADR and the total number of people are directly proportional to each other.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# The business objectives have been successfully achieved through various visualizations and analyses.
#
# 1. By using a pie chart distribution, the client can identify the months with high revenue generation.
#
# 2. The bar chart distribution highlights which room types are most reserved and the popular months for visitors, enabling the client to be well-prepared in advance.
#
# 3. Outliers, such as a significant reduction in ADR with higher visitor numbers, were shown in a scatter plot, leading to the suggestion of engaging with offices for bulk bookings during off-seasons to generate extra revenue.
#
# 4. Showing the trend of visitor arrivals helps the client plan and engage visitors in advance for entertainment and leisure activities.
#
# 5. The correlation between values is also presented, helping the client focus on enhancing percentages lying within those numbers through various means.
#
# By achieving these objectives, the hotel business can improve revenue generation, customer satisfaction, and employee retention, leading to an overall enhancement of their hospitality services.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. City Hotel seems to be more preferred among travelers, generating more revenue and profit compared to other hotels.
#
# 2. July and August witness the highest number of bookings as compared to the rest of the months.
#
# 3. Room Type A is the most preferred choice among travelers for accommodations.
#
# 4. The majority of bookings are made from Portugal and Great Britain.
#
# 5. Most guests tend to stay in the hotels for 1-4 days.
#
# 6. City Hotel has a higher guest retention rate compared to other hotels.
#
# 7. Around one-fourth of the total bookings get canceled, with City Hotel having the highest cancellation rate.
#
# 8. New guests tend to cancel bookings more frequently than repeat customers.
#
# 9. Factors like lead time, number of days in the waiting list, or the assignation of reserved rooms to customers do not significantly affect the cancellation of bookings.
#
# 10. Corporate guests have the highest percentage of repeat bookings, while TA/TO has the lowest. In the case of canceled bookings, TA/TO has the highest percentage, while Corporate has the lowest.
#
# 11. The length of stay tends to decrease as ADR increases, probably to reduce costs.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
